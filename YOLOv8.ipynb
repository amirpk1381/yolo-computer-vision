# %%
import cv2
from    ultralytics import YOLO

# %%
model = YOLO('yolov8m-cls.pt')

# %%
C:\Users\ASUS\Desktop\img.jpg

# %%
results = model(source=r"C:\Users\ASUS\Desktop\img.jpg"  ,show= True , conf=0.4)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# image 1/1 C:\Users\ASUS\Desktop\img.jpg: 448x640 9 persons, 53.3ms
# Speed: 3.5ms preprocess, 53.3ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)

# %%
model = YOLO('yolov8n-pose.pt')

# %%
results = model(source=r"C:\Users\ASUS\Desktop\img.jpg"  ,show= True , conf=0.4)
# Out:
# image 1/1 C:\Users\ASUS\Desktop\img.jpg: 448x640 9 persons, 53.3ms
# Speed: 3.4ms preprocess, 53.3ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)

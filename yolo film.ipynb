# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n-pose.pt')

# %%
import os

# %%
dek = os.path.expanduser("~")

# %%
dek
# Out:
# 'C:\\Users\\ASUS'

# %%
path = os.path.join(dek , 'Desktop')

# %%
path = os.path.join(path , 'walkinggg.mov')

# %%
path
# Out:
# 'C:\\Users\\ASUS\\Desktop\\walkinggg.mov'

# %%
result = model.predict(source=path ,show = True , conf = 0.5)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/278) C:\Users\ASUS\Desktop\walkinggg.mov: 384x640 5 persons, 41.7ms
# video 1/1 (frame 2/278) C:\Users\ASUS\Desktop\walkinggg.mov: 384x640 4 persons, 41.3ms
# video 1/1 (frame 3/278) C:\Users\ASUS\Desktop\walkinggg.mov: 384x640 4 persons, 39.1ms
# video 1/1 (frame 4/278) C:\Users\ASUS\Desktop\walkinggg.mov: 384x640 5 persons, 38.6ms
# ...

# %%
boxes = result[0].boxes

# %%
boxes.xyxy
# Out:
# tensor([[ 563.5837,  276.6110,  678.7451,  494.2363],
#         [1531.8279,  554.0747, 1598.3875,  771.6857],
#         [1370.1550,  674.6641, 1441.8060,  895.9534],
#         [ 392.1396,  384.4538,  471.2928,  588.7375],
#         [ 269.6537,  299.4443,  342.5648,  487.9293]], device='cuda:0')

# %%
boxes.cls
# Out:
# tensor([0., 0., 0., 0., 0.], device='cuda:0')

# %%
boxes.conf
# Out:
# tensor([0.7367, 0.7332, 0.7117, 0.6015, 0.5397], device='cuda:0')
